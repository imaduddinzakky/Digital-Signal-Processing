# %%
import pywt;
import numpy as np; 
import matplotlib.pyplot as plt;

x = np.genfromtxt('signal.txt');
coeffs = pywt.wavedec(x, 'db3', level=3)
cA3, cD3, cD2, cD1 = coeffs
fig, ax = plt.subplots(2, 3, figsize=(20,15))
ax[0,0].plot(x)
ax[0,1].plot(cD1)
ax[0,2].plot(cD2)
ax[1,0].plot(cD3)
ax[1,1].plot(cA3)

x_reconst=pywt.waverec([cA3, cD3, cD2, cD1] , 'db3');
ax[1,2].plot(x_reconst)
ax[0,0].title.set_text('Sinyal Asli')
ax[0,1].title.set_text('Detail 1')
ax[0,2].title.set_text('Detail 2')
ax[1,0].title.set_text('Detail 3')
ax[1,1].title.set_text('Approx 3')
ax[1,2].title.set_text('Sinyal Rekonstruksi')

# %%
import numpy as np
import matplotlib.pyplot as plt

#SIGNAL
y=np.genfromtxt('data1.txt')
N=y.size

#FFT
X=np.fft.fft(y)
x_mag=np.abs(X)/N


#PLOT
fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1, figsize=(20,15))
major_ticks = np.arange(0, 202, 20)
minor_ticks = np.arange(0, 202, 5)

ax1.set_xticks(major_ticks)
ax1.set_xticks(minor_ticks, minor=True)
ax1.set_yticks(major_ticks)
ax1.set_yticks(minor_ticks, minor=True)
ax2.set_xticks(major_ticks)
ax2.set_xticks(minor_ticks, minor=True)
ax2.set_yticks(major_ticks)
ax2.set_yticks(minor_ticks, minor=True)

ax1.plot(y)
ax2.plot(x_mag, '.-')
ax1.grid(which='both')
ax2.grid(which='both')
ax1.grid(which='minor', alpha=0.2)
ax1.grid(which='major', alpha=0.5)
ax2.grid(which='minor', alpha=0.2)
ax2.grid(which='major', alpha=0.5)
plt.show()

# %%
import pywt;
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('data1.txt')
coef, freqs=pywt.cwt(y,np.arange(1,5),'gaus1')
plt.matshow(coef)
plt.show()

# %%
import pywt;
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('data1.txt')
cwtmatr, freqs = pywt.cwt(y, np.arange(1,5), 'mexh')
plt.imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())  
plt.show()

# %%
import pywt;
import numpy as np; 
import matplotlib.pyplot as plt;

x = np.genfromtxt('data1.txt');
coeffs = pywt.wavedec(x, 'db4', level=4)
cA4, cD4, cD3, cD2, cD1 = coeffs
fig, ax = plt.subplots(2, 3, figsize=(20,15))
ax[0,0].plot(cD1)
ax[0,1].plot(cD2)
ax[0,2].plot(cD3)
ax[1,0].plot(cD4)
ax[1,1].plot(cA4)

x_reconst=pywt.waverec([cA4, cD4, cD3, cD2, cD1] , 'db4');
ax[1,2].plot(x_reconst)
ax[0,0].title.set_text('Detail 1')
ax[0,1].title.set_text('Detail 2')
ax[0,2].title.set_text('Detail 3')
ax[1,0].title.set_text('Detail 4')
ax[1,1].title.set_text('Approx 4')
ax[1,2].title.set_text('Sinyal Rekonstruksi')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt

#SIGNAL
y=np.genfromtxt('data2.txt')
N=y.size

#FFT
X=np.fft.fft(y)
x_mag=np.abs(X)/N


#PLOT
fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1, figsize=(20,15))
major_ticks = np.arange(0, 202, 20)
minor_ticks = np.arange(0, 202, 5)

ax1.set_xticks(major_ticks)
ax1.set_xticks(minor_ticks, minor=True)
ax1.set_yticks(major_ticks)
ax1.set_yticks(minor_ticks, minor=True)
ax2.set_xticks(major_ticks)
ax2.set_xticks(minor_ticks, minor=True)
ax2.set_yticks(major_ticks)
ax2.set_yticks(minor_ticks, minor=True)

ax1.plot(y)
ax2.plot(x_mag, '.-')
ax1.grid(which='both')
ax2.grid(which='both')
ax1.grid(which='minor', alpha=0.2)
ax1.grid(which='major', alpha=0.5)
ax2.grid(which='minor', alpha=0.2)
ax2.grid(which='major', alpha=0.5)
plt.show()

# %%
import pywt;
import numpy as np; 
import matplotlib.pyplot as plt;

x = np.genfromtxt('data2.txt');
coeffs = pywt.wavedec(x, 'db2', level=2)
cA2, cD2, cD1 = coeffs
fig, ax = plt.subplots(2, 3, figsize=(20,15))
ax[0,0].plot(x)
ax[0,1].plot(cD1)
ax[0,2].plot(cD2)
#ax[1,0].plot(cD3)
ax[1,1].plot(cA2)

x_reconst=pywt.waverec([cA2, cD2, cD1] , 'db2');
ax[1,2].plot(x_reconst)
ax[0,0].title.set_text('Sinyal Asli')
ax[0,1].title.set_text('Detail 1')
ax[0,2].title.set_text('Detail 2')
ax[1,0].title.set_text('Detail 3')
ax[1,1].title.set_text('Approx 3')
ax[1,2].title.set_text('Sinyal Rekonstruksi')

# %%
import matplotlib.pyplot as plt
import numpy as np

n=200
x=np.arange(n)
y_=np.random.uniform(-10,10,[n])

mu=0
sigma=0.01
e= np.random.normal(mu, sigma, n)
#stationary series
y=y_+e

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(x,y_)
plt.show()

X=np.fft.fft(y_)
x_mag=np.abs(X)/n
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(x_mag)
plt.show()

# %%
import numpy as np
import pywt
import matplotlib.pyplot as plt
import math
from math import ceil
N=64
t_n=50

xc = np.linspace(0, t_n, num=N)
xd = np.linspace(0, t_n, num=32)
sig = np.sin(2*np.pi * 64 * xc[:32]) * (1 - xd)
composite_signal3 = np.concatenate([np.zeros(32), sig[:32], np.zeros(N-32-32)])
plt.plot(sig)
plt.plot(composite_signal3)
X=np.fft.fft(composite_signal3)
x_mag=np.abs(X)/composite_signal3.size
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(5)
plt.plot(x_mag)
plt.show()
# Use the Daubechies wavelet
w = pywt.Wavelet('db1')
# Perform Wavelet transform up to log2(N) levels
lvls = ceil(math.log2(N))
coeffs = pywt.wavedec(composite_signal3, w, level=lvls)
# Each level of the WT will split the frequency band in two and apply a
# WT on the highest band. The lower band then gets split into two again,
# and a WT is applied on the higher band of that split. This repeats
# 'lvls' times.
#
# Since the amount of samples in each step decreases, we need to make
# sure that we repeat the samples 2^i times where i is the level so
# that at each level, we have the same amount of transformed samples
# as in the first level. This is only necessary because of plotting.
cc = np.abs(np.array([coeffs[-1]]))
for i in range(lvls - 1):
    cc = np.concatenate(np.abs([cc, np.array([np.repeat(coeffs[lvls - 1 - i], pow(2, i + 1))])]))

plt.figure()
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.title('Discrete Wavelet Transform')
# X-axis has a linear scale (time)
x = np.linspace(start=0, stop=1, num=N//2)
# Y-axis has a logarithmic scale (frequency)
y = np.logspace(start=lvls-1, stop=0, num=lvls, base=2)
X, Y = np.meshgrid(x, y)
plt.pcolormesh(X, Y, cc)

use_log_scale = False

if use_log_scale:
    plt.yscale('log')
else:
    yticks = [pow(2, i) for i in range(lvls)]
    plt.yticks(yticks)

plt.tight_layout()
plt.show()
print(lvls)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 6
